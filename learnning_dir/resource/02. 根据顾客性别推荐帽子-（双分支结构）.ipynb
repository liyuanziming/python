# %% [markdown]
# # 1. 获取顾客属性
#
# 运行下方代码，获取图像中顾客的属性

# %%
from utils.detect_face import *

url = "face/1.jpg" # 指定图像路径
img = get_image(url) # 获取路径url下的图像，并将图像存储在变量中
display_img(img)
gender, age = predict_age_and_gender(img) # 获取指定图像中人的性别，年龄，使用变量gender、age接收

print(f"图像中人脸的性别为：{gender}") # 输出gender变量的值
print(f"图像中人脸的年龄段为：{age}") # 输出age变量的值
# Out:
# 图像中人脸的性别为：Female
# 图像中人脸的年龄段为：(25, 32)

# %% [markdown]
# # 2. 根据顾客性别推荐主打帽子
#
# ## <font color = "blue">【练习】根据推荐规则补全代码实现基于性别的推荐</font>
#
# 基于性别的推荐规则如下：
# 1. 男性的顾客推荐编号为"8.jpg"的帽子；
# 2. 女性顾客推荐编号为"62.jpg"的帽子；
#
# 为了完成本节实验任务，将用到hat_recommend()函数：
#
# 请根据推荐规则，补全下方代码（补全代码时需要删除下划线），完成帽子推荐。

# %%
from utils.hat import *

# 根据年龄采用分支结构进行推荐
if gender == 'Male': # 如果性别为男，属于规则1
    hat_recommend(img, "8.jpg") # 推荐编号为"8.jpg"的帽子
else:
    hat_recommend(____, "____")

# %% [markdown]
# ## <font color = "blue">【练习】更改判断条件</font>
#
# `if`语句进行判断时，先判断性别是否女，该如何修改程序呢？

# %%
# 在下方尝试编写并完成练习
